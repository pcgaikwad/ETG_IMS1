# %%
products={'10101': {'Exp_date': 'May_2022',
  'Net_weight': '200g',
  'Price': 200,
  'Type_of_product': 'Sweets',
  'discount': 10,
  'product_name': 'Chocolate',
  'quantity': 65},
 '10102': {'Exp_date': 'Jun_2022',
  'Net_weight': '600g',
  'Price': 35,
  'Type_of_product': 'drink',
  'discount': 1,
  'product_name': 'Frooty',
  'quantity': 13},
 '10103': {'Exp_date': 'Dec_2022',
  'Net_weight': '35',
  'Price': 42,
  'Type_of_product': 'medicine',
  'discount': 1,
  'product_name': 'zendu balm',
  'quantity': 56},
  '10104': {'Exp_date': 'Oct_2021',
  'Net_weight': '1 unit',
  'Price': 8,
  'Type_of_product': 'Food',
  'discount': 1,
  'product_name': 'Egg',
  'quantity': 112},
 '10105': {'Exp_date': 'Dec_2024',
  'Net_weight': '1unit',
  'Price': 10,
  'Type_of_product': 'stationary',
  'discount': 1,
  'product_name': 'Stylo pen black',
  'quantity': 94}, 10106: {'Exp_date': 'DEC_2021',
  'Net_weight': '500g',
  'Price': 99,
  'Type_of_product': 'Fruit',
  'discount': 10,
  'product_name': 'Mango',
  'quantity': 82},
 10110: {'Exp_date': 'DEC_2021',
  'Net_weight': '500g',
  'Price': 99,
  'Type_of_product': 'Fruit',
  'discount': 10,
  'product_name': 'Banana',
  'quantity': 82},
 10114: {'Exp_date': 'DEC_2021',
  'Net_weight': '500g',
  'Price': 99,
  'Type_of_product': 'Fruit',
  'discount': 10,
  'product_name': 'Watermelon',
  'quantity': 82},
 10118: {'Exp_date': 'DEC_2021',
  'Net_weight': '500g',
  'Price': 99,
  'Type_of_product': 'Fruit',
  'discount': 10,
  'product_name': 'Papaya',
  'quantity': 82},
 10122: {'Exp_date': 'DEC_2021',
  'Net_weight': '500g',
  'Price': 99,
  'Type_of_product': 'Fruit',
  'discount': 10,
  'product_name': 'Pear',
  'quantity': 82},
 10126: {'Exp_date': 'DEC_2021',
  'Net_weight': '500g',
  'Price': 99,
  'Type_of_product': 'Fruit',
  'discount': 10,
  'product_name': 'Oranage',
  'quantity': 82},
   10107: {'Exp_date': 'DEC_2020',
  'Net_weight': '100g',
  'Price': 10220,
  'Type_of_product': 'Snacks',
  'discount': 15,
  'product_name': "Haldiram's Bhujia Sev: ",
  'quantity': 166},
 10111: {'Exp_date': 'DEC_2020',
  'Net_weight': '100g',
  'Price': 10220,
  'Type_of_product': 'Snacks',
  'discount': 15,
  'product_name': "Chheda's Mix Farsan",
  'quantity': 162},
 10115: {'Exp_date': 'DEC_2020',
  'Net_weight': '100g',
  'Price': 10220,
  'Type_of_product': 'Snacks',
  'discount': 15,
  'product_name': 'Rajam Snacks Garlic Mixture',
  'quantity': 158},
 10119: {'Exp_date': 'DEC_2020',
  'Net_weight': '100g',
  'Price': 10220,
  'Type_of_product': 'Snacks',
  'discount': 15,
  'product_name': 'Khatta Meetha',
  'quantity': 154},
 10123: {'Exp_date': 'DEC_2020',
  'Net_weight': '100g',
  'Price': 10220,
  'Type_of_product': 'Snacks',
  'discount': 15,
  'product_name': 'Farali Chivda',
  'quantity': 150},
 10127: {'Exp_date': 'DEC_2020',
  'Net_weight': '100g',
  'Price': 10220,
  'Type_of_product': 'Snacks',
  'discount': 15,
  'product_name': 'Moong Dal',
  'quantity': 146},
 10131: {'Exp_date': 'DEC_2020',
  'Net_weight': '100g',
  'Price': 10220,
  'Type_of_product': 'Snacks',
  'discount': 15,
  'product_name': 'Laxi Poha CHiwda',
  'quantity': 142},
  10108: {'Exp_date': 'DEC_2020',
  'Net_weight': '1kg',
  'Price': 292,
  'Type_of_product': 'Staples',
  'discount': 15,
  'product_name': ' Wheate Atta',
  'quantity': 145},
 10112: {'Exp_date': 'DEC_2020',
  'Net_weight': '1kg',
  'Price': 288,
  'Type_of_product': 'Staples',
  'discount': 15,
  'product_name': 'Chakki Atta',
  'quantity': 141},
 10116: {'Exp_date': 'DEC_2020',
  'Net_weight': '1kg',
  'Price': 284,
  'Type_of_product': 'Staples',
  'discount': 15,
  'product_name': 'Dry fruits',
  'quantity': 137},
 10120: {'Exp_date': 'DEC_2020',
  'Net_weight': '1kg',
  'Price': 280,
  'Type_of_product': 'Staples',
  'discount': 15,
  'product_name': 'Sugandi modak',
  'quantity': 133},
 10124: {'Exp_date': 'DEC_2020',
  'Net_weight': '1kg',
  'Price': 276,
  'Type_of_product': 'Staples',
  'discount': 15,
  'product_name': 'Modak Flour',
  'quantity': 129},
 10128: {'Exp_date': 'DEC_2020',
  'Net_weight': '1kg',
  'Price': 272,
  'Type_of_product': 'Staples',
  'discount': 15,
  'product_name': 'Rice atta',
  'quantity': 125},
 10132: {'Exp_date': 'DEC_2020',
  'Net_weight': '1kg',
  'Price': 268,
  'Type_of_product': 'Staples',
  'discount': 15,
  'product_name': 'Kuttu atta',
  'quantity': 121}, 20201: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 299,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'Red Label',
  'quantity': 344},
 20202: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 298,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'tata gold tea',
  'quantity': 343},
 20203: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 297,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'Agni leaf tea',
  'quantity': 342},
 20204: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 296,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'Wagh bakri tea',
  'quantity': 341},
 20205: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 295,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'maza',
  'quantity': 340},
 20206: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 294,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'paper boat aamras',
  'quantity': 339},
 20207: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 293,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'real fruit ',
  'quantity': 338},
 20208: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 292,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'Real Fruit Power Mosambi Juice ',
  'quantity': 337},
 20209: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 291,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'B Natural Litchi Juice ',
  'quantity': 336},
 20210: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 290,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'Minute Maid Mixed Fruit Juice ',
  'quantity': 335},
 20211: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 289,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'Sprite',
  'quantity': 334},
 20212: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 288,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'Fanta',
  'quantity': 333},
 20213: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 287,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'Thums up',
  'quantity': 332},
 20214: {'Exp_date': 'NOV_2023',
  'Net_weight': '1L',
  'Price': 286,
  'Type_of_product': 'Beverages',
  'discount': 20,
  'product_name': 'Bisleri Limonta',
  'quantity': 331}}

# %%
products
# Out:
# {'10101': {'Exp_date': 'May_2022',
#   'Net_weight': '200g',
#   'Price': 200,
#   'Type_of_product': 'Sweets',
#   'discount': 10,
#   'product_name': 'Chocolate',
#   'quantity': 65},
#  '10102': {'Exp_date': 'Jun_2022',
#   'Net_weight': '600g',
#   'Price': 35,
#   'Type_of_product': 'drink',
#   'discount': 1,
#   'product_name': 'Frooty',
#   'quantity': 13},
#  '10103': {'Exp_date': 'Dec_2022',
#   'Net_weight': '35',
#   'Price': 42,
#   'Type_of_product': 'medicine',
#   'discount': 1,
#   'product_name': 'zendu balm',
#   'quantity': 56},
#  '10104': {'Exp_date': 'Oct_2021',
#   'Net_weight': '1 unit',
#   'Price': 8,
#   'Type_of_product': 'Food',
#   'discount': 1,
#   'product_name': 'Egg',
#   'quantity': 112},
#  '10105': {'Exp_date': 'Dec_2024',
#   'Net_weight': '1unit',
#   'Price': 10,
#   'Type_of_product': 'stationary',
#   'discount': 1,
#   'product_name': 'Stylo pen black',
#   'quantity': 94},
#  10106: {'Exp_date': 'DEC_2021',
#   'Net_weight': '500g',
# ...

# %% [markdown]
# **Creating Json file**
#
# *   List item
# *   List item

# %%
import json
import time
import random

# %%
 js=json.dumps(products)

# %%
js
# Out:
# '{"10101": {"Exp_date": "May_2022", "Net_weight": "200g", "Price": 200, "Type_of_product": "Sweets", "discount": 10, "product_name": "Chocolate", "quantity": 65}, "10102": {"Exp_date": "Jun_2022", "Net_weight": "600g", "Price": 35, "Type_of_product": "drink", "discount": 1, "product_name": "Frooty", "quantity": 13}, "10103": {"Exp_date": "Dec_2022", "Net_weight": "35", "Price": 42, "Type_of_product": "medicine", "discount": 1, "product_name": "zendu balm", "quantity": 56}, "10104": {"Exp_date": "Oct_2021", "Net_weight": "1 unit", "Price": 8, "Type_of_product": "Food", "discount": 1, "product_name": "Egg", "quantity": 112}, "10105": {"Exp_date": "Dec_2024", "Net_weight": "1unit", "Price": 10, "Type_of_product": "stationary", "discount": 1, "product_name": "Stylo pen black", "quantity": 94}, "10106": {"Exp_date": "DEC_2021", "Net_weight": "500g", "Price": 99, "Type_of_product": "Fruit", "discount": 10, "product_name": "Mango", "quantity": 82}, "10110": {"Exp_date": "DEC_2021", "Net_wei
# ...

# %%
fd=open("record.json",'w')
txt=fd.write(js)
fd.close()

# %% [markdown]
# **Loading Json file**

# %%
fd=open("record.json",'r')
txt=fd.read()
fd.close()

products= json.loads(txt)

# %% [markdown]
# ** *italicized text*Displaying Product list**

# %%
total=0
items=[]
pid=[]
print("PRODUCT ID  \t","\t\tPRODUCT NAME")
for i in products:
    items.append(products[i]["product_name"])
    total=total+1
    pid.append(i)
    print(" ",i,"\t\t\t",products[i]["product_name"])
print("\nTotal Items you can purchases are : ",total)

items.sort()
# Out:
# PRODUCT ID  	 		PRODUCT NAME
#   10101 			 Chocolate
#   10102 			 Frooty
#   10103 			 zendu balm
#   10104 			 Egg
#   10105 			 Stylo pen black
#   10106 			 Mango
#   10110 			 Banana
#   10114 			 Watermelon
#   10118 			 Papaya
#   10122 			 Pear
#   10126 			 Oranage
#   10107 			 Haldiram's Bhujia Sev:
#   10111 			 Chheda's Mix Farsan
#   10115 			 Rajam Snacks Garlic Mixture
#   10119 			 Khatta Meetha
#   10123 			 Farali Chivda
#   10127 			 Moong Dal
#   10131 			 Laxi Poha CHiwda
#   10108 			  Wheate Atta
#   10112 			 Chakki Atta
#   10116 			 Dry fruits
#   10120 			 Sugandi modak
#   10124 			 Modak Flour
#   10128 			 Rice atta
#   10132 			 Kuttu atta
#   20201 			 Red Label
#   20202 			 tata gold tea
#   20203 			 Agni leaf tea
#   20204 			 Wagh bakri tea
#   20205 			 maza
#   20206 			 paper boat aamras
#   20207 			 real fruit
#   20208 			 Real Fruit Power Mosambi Juice
#   20209 			 B Natural Litchi Juice
#   20210 			 Minute Maid Mixed Fruit Juice
# ...

# %% [markdown]
# **Purchasing as well as updating invetory**

# %%
prod=[]
num=[]
lon=len(items)
NAME=str(input("Enter your Name : "))
MOBILE=str(input("Enter your Mobile No : "))
for e in range(1,2):
      print()
      print(" \t\t !!! NOTE:   TYPE  '0' FOR OVER  !!! ")
      print(" \t\t Enter Items which you want with Quantity  ")
      print()
      for j in range(lon + 10):
          buyId=str(input("Enter the id of product which u want to buy or press '0' to finsish shopping: "))
          
          if buyId!="0":
               prod.append(buyId)
               print("---------------********Details**********-----------------")
               print("Name of Product is: ",products[buyId]["product_name"])
               print("Price of each Product is: ",products[buyId]["Price"])
               buyQuant=int(input("Enter the quantity "))
               print("----------------------------------------------------------")
              
               if (int(products[buyId]['quantity'])>buyQuant):
                   num.append(buyQuant)
                   products[buyId]['quantity']=products[buyId]['quantity']-buyQuant
               else:
                  print("We don't have sufficient quantity in our inventory....")
                  print("----------------------------------------------------------")

          else:
               break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     618         """
# --> 619         parts = [self.recv(flags, copy=copy, track=track)]
#     620         # have first part already, only loop while more to receive
#
# ...

# %% [markdown]
# **Bill**

# %%
Time=time.ctime()
Time=list(Time.split(' '))
Time.pop(2)
DATE=Time[1]+" "+Time[2]+" "+Time[4]
TIME=Time[3]
BILL= random.randint(10000,20000)
BILL_NO=round(BILL*7.156)

# %%
Id=[]
discount=[]
Price=[]
pTotal=[]
Type_of_product=[]
Actual_Total=[]
plistId=[]



length=len(prod)
for i in range(length):
    S_NO=i+1
    Item=prod[i]
    quantity=num[i]
    for j in products:
        if j == Item: 
             Id.append(j)
             Type_of_product.append(products[j]["Type_of_product"])
             Price.append(products[j]["Price"])
             discount.append(products[j]["discount"])
             pTotal.append(quantity * (Price[i]-discount[i]))
             Actual_Total.append(products[j]["Price"]*num[i])

# %%
TP=0      #TOTAL PRICE
TD=0      # TOTAL DISCOUNT ( BASED ON ONE QUANTITY  )
TM=0      # TOTAL MRP 
TQ=0      # TOTAL QUANTITY
TI=0      # TOTAL ITEMS
TP=sum(pTotal)
TD=sum(discount)
TM=sum(Actual_Total)
TQ=sum(num)
TI=len(prod)
Save=TM-TP

# %%
USER=input("enter Your User name")
USER_ID=str(input("ENTER USER ID : "))
sym=u"\u20B9"
# Out:
# enter Your User nameasd
# ENTER USER ID : 5555

# %%
print("\t\t\t\t P_MART BULDANA \n\t\t\t\tMAHARASHTRA ,INDIA \n\t\t\t\t MOB:9157777774 ")
print("  ****************************************************************************************** ")
print("        BILL NO : "+str(BILL_NO)+"  \t\t\t\t USER NAME : "+USER.upper())
print("  CUSTOMER NAME : "+NAME.upper()+"\t\t\t\t USER ID   : "+USER_ID.upper())
print("      MOBILE NO : "+MOBILE+"\t\t\t\t DATE\t   :",DATE)
print("\t\t\t\t\t\t\t TIME\t   :",TIME)
print("  ****************************************************************************************** ")
print(" \t\t\t\t PRODUCTS LIST")
print("_____________________________________________________________________________________________")
print("S NO  Product ID   Items Name \t  Category \tQuantity  MRP"+"( "+sym+")"+"  Discount"+"( "+sym+")"+"   Total"+"( "+sym+")")
print("_____________________________________________________________________________________________")
for i in range (length):
    S_No=str(i+1)
    Item=str(products[prod[i]]["product_name"])
    quantity=str(num[i])
    print(" "+S_No+"\t"+Id[i]+"\t     "+Item.upper()+"\t   "+Type_of_product[i]+"\t   "+str(quantity)+"\t   "+str(Price[i])+"\t       "+str(discount[i])+"\t   "+str(round(pTotal[i],2)))
print("_____________________________________________________________________________________________")
print("                                                \t\t  GRAND TOTAL : "+sym+" "+str(round(TP,2)))
print()
print("_____________________________________________________________________________________________")
print()
print("        TOTAL ITEMS    : "+str(TI)+"  \t\t\t\t ACTUAL TOTAL MRP     : "+sym+" "+str(round(TM,2)))
print("        TOTAL QUANTITY : "+str(TQ)+"  \t\t\t\t DISCOUNT PRICE       : "+sym+" "+str(round(TD,2)))
print()
print("\t\t\t\t!!!  CONGRATS  !!!")
print(" \t\t\t    YOU HAVE SAVED "+sym+" "+str(round(Save,2))+" RUPEES    ")
print("_____________________________________________________________________________________________")
print(" \t   ------------  GOODS ONCE SOLD CANNOT BE TAKEN BACK   -------------   ")
print("  \t                    THANK YOU !   VISIT AGAIN !                        ")
# Out:
# 				 P_MART BULDANA
# 				MAHARASHTRA ,INDIA
# 				 MOB:9157777774
#   ******************************************************************************************
#         BILL NO : 142218  				 USER NAME : ASD
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8c68c55a4557> in <module>()
#       2 print("  ****************************************************************************************** ")
#       3 print("        BILL NO : "+str(BILL_NO)+"  \t\t\t\t USER NAME : "+USER.upper())
# ----> 4 print("  CUSTOMER NAME : "+NAME.upper()+"\t\t\t\t USER ID   : "+USER_ID.upper())
#       5 print("      MOBILE NO : "+MOBILE+"\t\t\t\t DATE\t   :",DATE)
#       6 print("\t\t\t\t\t\t\t TIME\t   :",TIME)
#
# NameError: name 'NAME' is not defined

# %%
products
# Out:
# {'10101': {'Exp_date': 'May_2022',
#   'Net_weight': '200g',
#   'Price': 200,
#   'Type_of_product': 'Sweets',
#   'discount': 10,
#   'product_name': 'Chocolate',
#   'quantity': 65},
#  '10102': {'Exp_date': 'Jun_2022',
#   'Net_weight': '600g',
#   'Price': 35,
#   'Type_of_product': 'drink',
#   'discount': 1,
#   'product_name': 'Frooty',
#   'quantity': 13},
#  '10103': {'Exp_date': 'Dec_2022',
#   'Net_weight': '35',
#   'Price': 42,
#   'Type_of_product': 'medicine',
#   'discount': 1,
#   'product_name': 'zendu balm',
#   'quantity': 56},
#  '10104': {'Exp_date': 'Oct_2021',
#   'Net_weight': '1 unit',
#   'Price': 8,
#   'Type_of_product': 'Food',
#   'discount': 1,
#   'product_name': 'Egg',
#   'quantity': 112},
#  '10105': {'Exp_date': 'Dec_2024',
#   'Net_weight': '1unit',
#   'Price': 10,
#   'Type_of_product': 'stationary',
#   'discount': 1,
#   'product_name': 'Stylo pen black',
#   'quantity': 94},
#  '10106': {'Exp_date': 'DEC_2021',
#   'Net_weight': '500g',
# ...

# %%
p_id=input("Enter Id of Product:- ")
p_name=input("Enter name of the product:- ")
ptype=input("Enter the type of the product:- ")
rs=int(input("Enter the price of the product:- "))
quantity=int(input("Enter the quantity of the product:- "))
exp=input("Enter the expiry date of the product:- ")
wt=input("Enter the weight of the product:- ")
ds=int(input("Enter discount amount for "+ p_name +":- "))

#updating the original product record dictionary with a new entry having product id as prod_id

products[p_id]={'product_name':p_name,'Type_of_product':ptype,'Price':rs,'quantity':quantity,'Exp_date':exp,"Net_weight":wt,"discount":ds}
